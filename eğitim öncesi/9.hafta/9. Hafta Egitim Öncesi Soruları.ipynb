# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
# 1.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, capacity):
        self.capacity = capacity
        
class Bus(Vehicle):
    def __init__(self, capacity=50):
        super().__init__(capacity)
        
    def seating_capacity(self):
        return self.capacity
bus = Bus()
print("Bus Seating Capacity:", bus.seating_capacity()) # Output: Bus Seating Capacity: 50
# Out:
# Bus Seating Capacity: 50

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

class School_bus(Vehicle):
    def __init__(self, make, model, year, num_seats):
        super().__init__(make, model, year)
        self.num_seats = num_seats
